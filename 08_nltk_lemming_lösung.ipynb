# %%
# !pip install HanTa
# Out:
# Collecting HanTa
#   Downloading https://files.pythonhosted.org/packages/c9/b5/4044815d9501eae53b3e09356e8bd35dd7f96ccda0894d6c430a579c6fdb/HanTa-0.2.0-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 5.1MB/s
# Installing collected packages: HanTa
# Successfully installed HanTa-0.2.0

# %%
import pandas as pd
import nltk
import numpy as np
from nltk.corpus import stopwords
from HanTa import HanoverTagger as ht

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#nltk.FreqDist(sum(daten_nltk_tokens, [])).plot(20, cumulative=False)

# %%
filename=open("/content/drive/MyDrive/vbg/test_part.txt","r")
tokenizer = nltk.RegexpTokenizer("[\w']+")
tokens_part = []
for line in filename.readlines():
    tokens_part+=tokenizer.tokenize(line)
print(tokens_part)
tokens_part = [token.lower() for token in tokens_part]
#tokens_part
#nltk.FreqDist(tokens_part).plot(20, cumulative=False)
# Out:
# ['Versicherter', 'ist', 'auf', 'dem', 'Fahrrad', 'auf', 'dem', 'Nachhauseweg', 'verunfallt', 'Ein', 'stehendes', 'Auto', 'habe', 'die', 'Tür', 'geöffnet', 'der', 'Versicherte', 'konnte', 'nicht', 'mehr', 'bremsen', 'und', 'ist', 'gegen', 'die', 'Autotür', 'gefahren', 'Versicherter', 'war', 'behelmt', 'kein', 'Kopfanprall', 'Tetanusschutz', 'nicht', 'sicher', 'intakt', 'wird', 'morgen', 'über', 'beim', 'niedergelassenen', 'Hausarzt', 'gprüft', 'und', 'ggf', 'nachgeholt', 'Unfallort', 'Berliner', 'Straße', 'Köln', 'Mühlheim', 'Unfallort', 'Der', 'Pat', 'ist', 'auf', 'Glatteis', 'ausgerutscht', 'und', 'dabei', 'die', 'Treppe', 'runtergerutscht', 'und', 'auf', 'die', 'li', 'Seite', 'gefallen', 'Auf', 'dem', 'WEg', 'zur', 'Arbeit', 'auf', 'Glatteis', 'ausgerutscht', 'und', 'auf', 'die', 'Knie', 'gefallen', 'Die', 'Versicherte', 'habe', 'ein', 'Garagentor', 'auf', 'dem', 'Kopf', 'bekommen', 'Fußläufige', 'Vorstellung', 'in', 'unserer', 'ZNA', 'Die', 'Verunfallte', 'habe', 'sich', 'bei', 'der', 'Arbeit', 'bei', 'einer', 'Inobhutnahme', 'eines', 'Kindes', 'das', 'rechte', 'Handgelenk', 'Hand', 'verdreht', 'Seitdem', 'habe', 'sie', 'Schmerzen', 'Rotationsbewegungen', 'des', 'Handgelenkes', 'vorbei', 'gofahron', 'Später', 'habe', 'er', 'durch', 'die', 'Polizei', 'erfahren', 'dass', 'es', 'lch', 'um', 'eine', 'Leiche', 'gehandelt', 'habe', 'D', 'Le', 'Patientin', 'ist', 'aut', 'dem', 'Weg', 'zur', 'Arbeit', 'mit', 'dem', 'rechten', 'Fuss', 'umgekniekt', 'Bereits', 'am', '14', '12', '2018', 'nach', 'dem', 'Tragen', 'eines', 'Tragestuhls', 'mit', 'Patienten', 'eine', 'Treppe', 'hinunter', 'und', 'Patienten', 'Transfer', 'in', 'den', 'Rettungswagen', 'Beim', 'Zurücklaufen', 'in', 'das', 'Auto', 'auf', 'ebenem', 'Untergrund', "'schnalzendes", "Geräusch'", 'linke', 'Wade', 'verspürt', 'Patietenzimmer', 'Station', '3', '1', 'die', 'Patient', 'wird', 'von', 'der', 'Pflegekraft', 'auf', 'dem', 'Boden', 'in', 'Rückenlage', 'vorgefunden', 'Die', 'Patientin', 'berichtet', 'von', 'der', 'Toilette', 'zurück', 'ins', 'Bett', 'gewollt', 'zu', 'haben', 'und', 'dabei', 'gestürzt', 'zu', 'sein', 'Die', 'genaue', 'Ursache', 'sei', 'Ihr', 'nicht', 'bewusst', 'L', 'Pat', 'wird', 'bodengebunden', 'ohne', 'Notarztbegleitung', 'über', 'Schockraum', 'in', 'die', 'Notaufnahme', 'gebracht', 'nachdem', 'sie', 'heute', 'die', 'Treppen', 'hinunter', 'gestürzt', 'und', 'direkt', 'auf', 'die', 'LWS', 'gefallen', 'sei', 'Sie', 'sei', 'nicht', 'bewusstlos', 'gewesen', 'sie', 'könne', 'sich', 'an', 'alles', 'erinnern', 'Keine', 'Übelkeit', 'kein', 'Erbrechen', 'Bei', 'Eintreffen', 'des', 'NA', 'GCS', '15', 'Vorerkrankungen', 'Faktor', 'VII', 'Mangel', 'Allergien', 'Metamizol', 'Medikation', 'keine', 'Die', 'UV', 'sei', 'mit', 'dem', 'li', 'Schienbein', 'gegen', 'einen', 'Kinderrollator', 'gestoßen', 'Im', 'Rahmen', 'seiner', 'beruflichen', 'Tätigkeit', 'durch', 'eine', 'fremde', 'Person', 'in', 'den', 'Daumen', 'der', 'rechten', 'Hand', 'gebissen', 'worden', 'Habe', 'hierbei', 'stichfeste', 'Handschuhe', 'getragen', 'Handschuh', 'allseits', 'vollständig', 'intakt', 'Der', 'Verletzte', 'ist', 'auf', 'Eis', 'ausgerutscht', 'und', 'auf', 'die', 'rechte', 'Seite', 'gefallen', 'Dabei', 'mit', 'Kopf', 'rechts', 'frontal', 'sowie', 'mit', 'linker', 'Hand', 'aufgekommen', 'Der', 'Patient', 'berichtet', 'dass', 'ihm', 'in', 'der', 'Arbeit', 'beim', 'Zug', 'rangieren', 'um', 'ca', '19', '30', 'Uhr', 'ein', 'anderer', 'ICE', 'mit', 'geringer', 'Geschwindigkeit', 'hinten', 'aufgefahren', 'ist', 'Der', 'Pat', 'ist', 'auf', 'der', 'Schafweide', 'gestürzt', 'und', 'hat', 'sich', 'das', 'rechte', 'Knie', 'verdreht', '3673', '2018', 'Chahoud', 'Heu', 'Der', 'UV', 'gibt', 'an', 'am', '08', '12', '2018', 'einen', 'Verkehrsunfall', 'auf', 'der', 'A3', 'erlitten', 'zu', 'haben', 'anschl', 'wurde', 'der', 'UV', 'in', 'einem', 'Offenbacher', 'Klinikum', 'zur', 'Überwachung', 'stationär', 'aufgenommen', 'Asklebius', 'Klinik', 'Offenbach', 'Bei', 'unauffälligem', 'Verlauf', 'sei', 'der', 'UV', 'a ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('punkt')
filename=open("/Users/ulizellbeck/Google Drive/vbg/test.txt","r")
tokenizer = nltk.RegexpTokenizer("[\w']+")
tokens = []
for line in filename.readlines():
    tokens+=tokenizer.tokenize(line)
tokens = [token.lower() for token in tokens]
tokens
nltk.FreqDist(tokens).plot(20, cumulative=False)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ulizellbeck/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Importieren der deutschen Stoppwörter mit der Funktion [stopwords]()

# %%
# Importieren der deutschen Stoppwörter
german_stop_words = stopwords.words('german')

tokens = [token for token in tokens if token not in german_stop_words]
nltk.FreqDist(tokens).plot(20, cumulative=False)

# %% [markdown]
# Löschen aller Tokens, die im Array "german_stop_words" vorkommen.
#
# Sieh dir dazu die Antwort bei[StackOverflow](https://stackoverflow.com/questions/2104305/finding-elements-not-in-a-list) an.

# %%
# Löschen aller Tokens, die im Array "german_stop_words" vorkommen
tokens_part = [token for token in tokens_part if token not in german_stop_words]
nltk.FreqDist(tokens_part).plot(20, cumulative=False)

# %% [markdown]
# Wende den selben Code auf das große File an:

# %%
tokens = [token for token in tokens if token not in german_stop_words]
nltk.FreqDist(tokens).plot(20, cumulative=False)

# %% [markdown]
# * Import des HannoverTagger wie in der offiziellen Demo [link](https://github.com/wartaal/HanTa/blob/master/Demo.ipynb)

# %%
tagger = ht.HanoverTagger('morphmodel_ger.pgz')

# %% [markdown]
# Erstellen der Tags mit der Funktion tag_sent. [Beispiel](https://textmining.wp.hs-hannover.de/Preprocessing.html#Lemmatisierung-und-Wortarterkennung)

# %%
tags_part = tagger.tag_sent(tokens_part)
print(tags_part)
# Out:
# [('versicherter', 'versichert', 'ADJA'), ('fahrrad', 'Fahrrad', 'NN'), ('nachhauseweg', 'nachhauseweg', 'ADV'), ('verunfallt', 'verunfallt', 'ADJD'), ('stehendes', 'stehend', 'ADJA'), ('auto', 'Auto', 'NN'), ('tür', 'Tür', 'NN'), ('geöffnet', 'öffnen', 'VVPP'), ('versicherte', 'versichern', 'VVFIN'), ('konnte', 'können', 'VMFIN'), ('mehr', 'mehr', 'PIS'), ('bremsen', 'bremsen', 'VVINF'), ('autotür', 'Autotür', 'NN'), ('gefahren', 'fahren', 'VVPP'), ('versicherter', 'versichern', 'ADJD'), ('behelmt', 'behelmt', 'FM'), ('kopfanprall', 'kopfanprall', 'FM'), ('tetanusschutz', 'Tetanusschutz', 'NE'), ('sicher', 'sicher', 'ADV'), ('intakt', 'intakt', 'ADJD'), ('morgen', 'morgen', 'ADV'), ('beim', 'beim', 'APPRART'), ('niedergelassenen', 'niedergelassen', 'ADJA'), ('hausarzt', 'Hausarzt', 'NN'), ('gprüft', 'Gprüft', 'NE'), ('ggf', 'Ggf', 'NE'), ('nachgeholt', 'nachgeholt', 'ADJD'), ('unfallort', 'unfallort', 'ADV'), ('berliner', 'berlin', 'ADJA'), ('straße', 'Straße', 'NN'), ('köln', 'Köln', 'NE'), ('mühlheim', 'Mühlheim', 'NE'), ('unfallort', 'Unfallort', 'NN'), ('pat', 'Pat', 'NE'), ('glatteis', 'Glatteis', 'NE'), ('ausgerutscht', 'ausgerutscht', 'ADJD'), ('dabei', 'dabei', 'PROAV'), ('treppe', 'Treppe', 'NN'), ('runtergerutscht', 'runterrutschen', 'VVPP'), ('li', 'Li', 'NE'), ('seite', 'Seite', 'NE'), ('gefallen', 'fallen', 'VVPP'), ('arbeit', 'Arbeit', 'NN'), ('glatteis', 'Glatteis', 'NN'), ('ausgerutscht', 'ausgerutscht', 'ADJD'), ('knie', 'Knie', 'NN'), ('gefallen', 'gefallen', 'VVINF'), ('versicherte', 'versichern', 'VVFIN'), ('garagentor', 'garagentor', 'FM'), ('kopf', 'Kopf', 'NE'), ('bekommen', 'bekommen', 'VVFIN'), ('fußläufige', 'fußläufig', 'ADJA'), ('vorstellung', 'Vorstellung', 'NN'), ('unserer', 'unser', 'PPOSAT'), ('zna', 'Zna', 'NE'), ('verunfallte', 'verunfallt', 'ADJA'), ('arbeit', 'Arbeit', 'NN'), ('inobhutnahme', 'inobhutnahm', 'ADJA'), ('kindes', 'Kind', 'NN'), ('rechte', 'rechter', 'ADJA'), ('handgelenk', 'Handgelenk', 'NN'), ('hand', 'Hand', 'NE'), ('verdreht', 'verdrehen', 'VVFIN'), ('seitdem', 'seitdem', 'PROAV'), ('schmerzen', 'Schmerz', 'NN'), ('rotationsbewegungen', 'rotationsbewegungen', 'ADJA'), ('handgelenkes', 'Handgelenk', 'NN'), ('vorbei', 'vorbei', 'ADV'), ('gofahron', 'Gofahron', 'NE'), ('später', 'spät', 'ADJD'), ('polizei', 'Polizei', 'NN'), ('erfahren', 'erfahren', 'VVFIN'), ('lch', 'Lch', 'NE'), ('leiche', 'Leiche', 'NN'), ('gehandelt', 'handeln', 'VVPP'), ('d', 'D', 'NE'), ('le', 'Le', 'NE'), ('patientin', 'Patientin', 'NE'), ('aut', 'aut', 'FM'), ('arbeit', 'Arbeit', 'NN'), ('rechten', 'rechter', 'ADJA'), ('fuss', 'Fuß', 'NN'), ('umgekniekt', 'umgekniekt', 'ADJD'), ('bereits', 'bereits', 'ADV'), ('14', '14', 'CARD'), ('12', '12', 'CARD'), ('2018', '2018', 'CARD'), ('tragen', 'tragen', 'VVFIN'), ('tragestuhls', 'tragestuhls', 'ADV'), ('patienten', 'Patient', 'NN'), ('treppe', 'Treppe', 'NN'), ('hinunter', 'hinunter', 'APPO'), ('patienten', 'Patient', 'NN'), ('transfer', 'Transfer', 'NN'), ('rettungswagen', 'rettungswagen', 'ADJD'), ('beim', 'beim', 'APPRART'), ('zurücklaufen', 'zurücklaufen', 'VVINF'), ('auto', 'Auto', 'NN'), ('ebenem', 'ebenem', 'FM'), ('untergrund', 'Untergrund', 'NN'), ("'schnalzendes", "'schnalzendes", 'FM'), ("geräusch'", "geräusch'", 'FM'), ('linke', 'linker', 'ADJA'), ('wade', 'Wade', 'NN'), ('verspürt', 'verspüren', 'VVFIN'), ('patietenzimmer', 'patietenzimmer', 'ADV'), ('station', 'Station', 'NN'), ('3', '3', 'CARD'), ('1', '1', 'CARD'), ('patient', 'Patient', 'NN'), ('pflegekraft', 'pflegekraft', 'ADJA'), ('boden', 'Boden', 'NN'), ('rückenlage', 'rückenlage', 'ADV'), ('vorgefunden', 'vorgefunden', 'ADJD'), ('patientin', 'Patient', 'NN'), ('berichtet', 'berichten', 'VVFIN'), ('toilette', 'Toilette', 'NN'), ('zurück', 'zurück', 'PTKVZ'), ('bett', 'Bett', 'NN'), ('gewollt', 'wollen', 'VMPP'), ('dabei', 'dabei', 'PROAV'), ('gestürzt', 'stürzen', 'VVPP'), ('genaue', 'genau', 'ADJA'), ('ursache', 'Ursache', 'NN'), ('sei', 'sein', 'VAFIN'), ('bewusst', 'bewissen', 'VVPP') ...

# %% [markdown]
# Erstellen einer Variable leamms, die nur den Teil "lemma" aus der Variable liest und stelle die Top 20 Wörter in einem Diagramm dar.

# %%
lemmas_part = [lemma for (word,lemma,pos) in tags_part]
nltk.FreqDist(lemmas_part).plot(20, cumulative=False)

# %%
tags = tagger.tag_sent(tokens)
print(tags)

# %%
filename=open("/content/drive/MyDrive/vbg/test.txt","r")
tags = []
i = 0
for line in filename.readlines():
    tags+= [lemma for (word,lemma,pos) in tagger.tag_sent(line)]
    if (i == 1000):
      print(i)
      i = 0
    i = i +1
print(tags)

# %%
freq = nltk.FreqDist(tokens)
tokens_dist = pd.DataFrame(list(freq.items()), columns = ["Word","Frequency"])

# %%
tokens_dist.tail()
# Out:
#                 Word  Frequency
# 150103  (í, í, CARD)          2
# 150104    (í, í, FM)          2
# 150105  (è, è, CARD)          1
# 150106    (â, â, FM)          1
# 150107    (², ², FM)          1

# %%
def analyzer_logging(x):
  return b

tokens_dist["Word_TAG"] = tokens_dist["Word"].apply(lambda x: analyzer_logging(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-59c47f1354f5> in <module>()
#       2   return b
#       3
# ----> 4 tokens_dist["Word_TAG"] = tokens_dist["Word"].apply(lambda x: analyzer_logging(x))
#
# NameError: name 'tokens_dist' is not defined

# %%
# %%bash
# mkdir treetagger
# cd treetagger
# # Download the tagger package for your system (PC-Linux, Mac OS-X, ARM64, ARMHF, ARM-Android, PPC64le-Linux).
# wget https://cis.lmu.de/~schmid/tools/TreeTagger/data/tree-tagger-linux-3.2.4.tar.gz
# tar -xzvf tree-tagger-linux-3.2.4.tar.gz
# # Download the tagging scripts into the same directory.
# wget https://cis.lmu.de/~schmid/tools/TreeTagger/data/tagger-scripts.tar.gz
# gunzip tagger-scripts.tar.gz
# # Download the installation script install-tagger.sh.
# wget https://cis.lmu.de/~schmid/tools/TreeTagger/data/install-tagger.sh
# # Download the parameter files for the languages you want to process.
# # list of all files (parameter files) https://cis.lmu.de/~schmid/tools/TreeTagger/#parfiles
# wget https://cis.lmu.de/~schmid/tools/TreeTagger/data/german.par.gz
# sh install-tagger.sh
# cd ..
# sudo pip install treetaggerwrapper
# Out:
# bin/
# bin/train-tree-tagger
# bin/separate-punctuation
# bin/tree-tagger
# bin/tree-tagger-flush
# cmd/
# cmd/lookup.perl
# COPYRIGHT
# doc/
# doc/sigdat95.pdf
# doc/nemlap94.pdf
# FILES
# README
# Release-Notes
#
# TreeTagger version for PC-Linux installed.
# German parameter file installed.
# Tagging scripts installed.
),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Fahrrad', pos='NN', lemma='Fahrrad'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Nachhauseweg', pos='NN', lemma='Nachhauseweg'),
#  Tag(word='verunfallt', pos='VVFIN', lemma='verunfallen'),
#  Tag(word='Ein', pos='ART', lemma='eine'),
#  Tag(word='stehendes', pos='ADJA', lemma='stehend'),
#  Tag(word='Auto', pos='NN', lemma='Auto'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Tür', pos='NN', lemma='Tür'),
#  Tag(word='geöffnet', pos='ADJD', lemma='geöffnet'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Versicherte', pos='NN', lemma='Versicherte'),
#  Tag(word='konnte', pos='VMFIN', lemma='können'),
#  Tag(word='nicht', pos='PTKNEG', lemma='nicht'),
#  Tag(word='mehr', pos='ADV', lemma='mehr'),
#  Tag(word='bremsen', pos='VVINF', lemma='bremsen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='gegen', pos='APPR', lemma='gegen'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Autotür', pos='NN', lemma='Autotür'),
#  Tag(word='gefahren', pos='VVPP', lemma='fahren'),
#  Tag(word='Versicherter', pos='NN', lemma='Versicherte'),
#  Tag(word='war', pos='VAFIN', lemma='sein'),
#  Tag(word='behelmt', pos='ADJD', lemma='behelmt'),
#  Tag(word='kein', pos='PIAT', lemma='keine'),
#  Tag(word='Kopfanprall', pos='NN', lemma='Kopfanprall'),
#  Tag(word='Tetanusschutz', pos='NN', lemma='Tetanusschutz'),
#  Tag(word='nicht', pos='PTKNEG', lemma='nicht'),
#  Tag(word='sicher', pos='ADJD', lemma='sicher'),
#  Tag(word='intakt', pos='ADJD', lemma='intakt'),
#  Tag(word='wird', pos='VAFIN', lemma='werden'),
#  Tag(word='morgen', pos='ADV', lemma='morgen'),
#  Tag(word='über', pos='APPR', lemma='über'),
#  Tag(word='beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='niedergelassenen', pos='ADJA', lemma='niedergelassen'),
#  Tag(word='Hausarzt', pos='NN', lemma='Hausarzt'),
#  Tag(word='gprüft', pos='VVFIN', lemma='gprüfen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='ggf', pos='NE', lemma='ggf'),
#  Tag(word='nachgeholt', pos='VVPP', lemma='nachholen'),
#  Tag(word='Unfallort', pos='NN', lemma='Unfallort'),
#  Tag(word='Berliner', pos='ADJA', lemma='Berliner'),
#  Tag(word='Straße', pos='NN', lemma='Straße'),
#  Tag(word='Köln', pos='NE', lemma='Köln'),
#  Tag(word='Mühlheim', pos='NN', lemma='Mühlheim'),
#  Tag(word='Unfallort', pos='NN', lemma='Unfallort'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Pat', pos='NE', lemma='Pat'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='Glatteis', pos='NN', lemma='Glatteis'),
#  Tag(word='ausgerutscht', pos='VVPP', lemma='ausrutschen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Treppe', pos='NN', lemma='Treppe'),
#  Tag(word='runtergerutscht', pos='VVPP', lemma='runterrutschen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='li', pos='ADJA', lemma='li'),
#  Tag(word='Seite', pos='NN', lemma='Seite'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='Auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='WEg', pos='ADV', lemma='weg'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='Glatteis', pos='NN', lemma='Glatteis'),
#  Tag(word='ausgerutscht', pos='VVPP', lemma='ausrutschen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Knie', pos='NE', lemma='Knie'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Versicherte', pos='NN', lemma='Versicherte'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='ein', pos='ART', lemma='eine'),
#  Tag(word='Garagentor', pos='NN', lemma='Garagentor'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Kopf', pos='NN', lemma='Kopf'),
#  Tag(word='bekommen', pos='VVINF', lemma='bekommen'),
#  Tag(word='Fußläufige', pos='ADJA', lemma='fußläufig'),
#  Tag(word='Vorstellung', pos='NN', lemma='Vorstellung'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='unserer', pos='PPOSAT', lemma='unser'),
#  Tag(word='ZNA', pos='NE', lemma='ZNA'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Verunfallte', pos='ADJA', lemma='verunfallt'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='Inobhutnahme', pos='NN', lemma='Inobhutnahme'),
#  Tag(word='eines', pos='ART', lemma='eine'),
#  Tag(word='Kindes', pos='NN', lemma='Kind'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='rechte', pos='ADJA', lemma='recht|rechts'),
#  Tag(word='Handgelenk', pos='NN', lemma='Handgelenk'),
#  Tag(word='Hand', pos='NN', lemma='Hand'),
#  Tag(word='verdreht', pos='ADJD', lemma='verdreht'),
#  Tag(word='Seitdem', pos='PAV', lemma='seitdem'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='Schmerzen', pos='NN', lemma='Schmerz'),
#  Tag(word='Rotationsbewegungen', pos='NN', lemma='Rotationsbewegung'),
#  Tag(word='des', pos='ART', lemma='die'),
#  Tag(word='Handgelenkes', pos='NN', lemma='Handgelenkes'),
#  Tag(word='vorbei', pos='ADV', lemma='vorbei'),
#  Tag(word='gofahron', pos='ADJD', lemma='gofahron'),
#  Tag(word='Später', pos='NN', lemma='Späte'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='durch', pos='APPR', lemma='durch'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Polizei', pos='NN', lemma='Polizei'),
#  Tag(word='erfahren', pos='VVFIN', lemma='erfahren'),
#  Tag(word='dass', pos='KOUS', lemma='dass'),
#  Tag(word='es', pos='PPER', lemma='es'),
#  Tag(word='lch', pos='NN', lemma='lch'),
#  Tag(word='um', pos='APPR', lemma='um'),
#  Tag(word='eine', pos='ART', lemma='eine'),
#  Tag(word='Leiche', pos='NN', lemma='Leiche'),
#  Tag(word='gehandelt', pos='VVPP', lemma='handeln'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='D', pos='NN', lemma='D'),
#  Tag(word='Le', pos='NE', lemma='Le'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='aut', pos='ADJD', lemma='aut'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Weg', pos='NN', lemma='Weg'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='rechten', pos='ADJA', lemma='recht|rechts'),
#  Tag(word='Fuss', pos='NN', lemma='Fuß'),
#  Tag(word='umgekniekt', pos='NN', lemma='umgekniekt'),
#  Tag(word='Bereits', pos='ADV', lemma='bereits'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='14', pos='ADJA', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='nach', pos='APPR', lemma='nach'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Tragen', pos='NN', lemma='Trage|Tragen'),
#  Tag(word='eines', pos='ART', lemma='eine'),
#  Tag(word='Tragestuhls', pos='NN', lemma='Tragestuhl'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='Patienten', pos='NN', lemma='Patient'),
#  Tag(word='eine', pos='ART', lemma='eine'),
#  Tag(word='Treppe', pos='NN', lemma='Treppe'),
#  Tag(word='hinunter', pos='PTKVZ', lemma='hinunter'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='Patienten', pos='NN', lemma='Patient'),
#  Tag(word='Transfer', pos='NN', lemma='Transfer'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Rettungswagen', pos='NN', lemma='Rettungswagen'),
#  Tag(word='Beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='Zurücklaufen', pos='NN', lemma='Zurücklaufen'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='Auto', pos='NN', lemma='Auto'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='ebenem', pos='ADJA', lemma='eben'),
#  Tag(word='Untergrund', pos='NN', lemma='Untergrund'),
#  Tag(word="'schnalzendes", pos='NN', lemma="'schnalzende"),
#  Tag(word="Geräusch'", pos='VVFIN', lemma="Geräusch'"),
#  Tag(word='linke', pos='ADJA', lemma='links'),
#  Tag(word='Wade', pos='NN', lemma='Wade'),
#  Tag(word='verspürt', pos='VVFIN', lemma='verspüren'),
#  Tag(word='Patietenzimmer', pos='ADJA', lemma='Patietenzimmer'),
#  Tag(word='Station', pos='NN', lemma='Station'),
#  Tag(word='3', pos='CARD', lemma='@card@'),
#  Tag(word='1', pos='CARD', lemma='@card@'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Patient', pos='NN', lemma='Patient'),
#  Tag(word='wird', pos='VAFIN', lemma='werden'),
#  Tag(word='von', pos='APPR', lemma='von'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Pflegekraft', pos='NN', lemma='Pflegekraft'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Boden', pos='NN', lemma='Boden'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='Rückenlage', pos='NN', lemma='Rückenlage'),
#  Tag(word='vorgefunden', pos='VVPP', lemma='vorfinden'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='von', pos='APPR', lemma='von'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Toilette', pos='NN', lemma='Toilette'),
#  Tag(word='zurück', pos='PTKVZ', lemma='zurück'),
#  Tag(word='ins', pos='APPRART', lemma='in+die'),
#  Tag(word='Bett', pos='NN', lemma='Bett'),
#  Tag(word='gewollt', pos='VMPP', lemma='wollen'),
#  Tag(word='zu', pos='PTKZU', lemma='zu'),
#  Tag(word='haben', pos='VAINF', lemma='haben'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='zu', pos='PTKZU', lemma='zu'),
#  Tag(word='sein', pos='VAINF', lemma='sein'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='genaue', pos='ADJA', lemma='genau'),
#  Tag(word='Ursache', pos='NN', lemma='Ursache'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='Ihr', pos='PPER', lemma='sie'),
#  Tag(word='nicht', pos='PTKNEG', lemma='nicht'),
#  Tag(word='bewusst', pos='ADJD', lemma='bewusst'),
#  Tag(word='L', pos='NN', lemma='L'),
#  Tag(word='Pat', pos='NE', lemma='Pat'),
#  Tag(word='wird', pos='VAFIN', lemma='werden'),
#  Tag(word='bodengebunden', pos='ADJD', lemma='bodengebunden'),
#  Tag(word='ohne', pos='APPR', lemma='ohne'),
#  Tag(word='Notarztbegleitung', pos='NN', lemma='Notarztbegleitung'),
#  Tag(word='über', pos='APPR', lemma='über'),
#  Tag(word='Schockraum', pos='NN', lemma='Schockraum'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Notaufnahme', pos='NN', lemma='Notaufnahme'),
#  Tag(word='gebracht', pos='VVPP', lemma='bringen'),
#  Tag(word='nachdem', pos='KOUS', lemma='nachdem'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='heute', pos='ADV', lemma='heute'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Treppen', pos='NN', lemma='Treppe'),
#  Tag(word='hinunter', pos='ADV', lemma='hinunter'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='direkt', pos='ADJD', lemma='direkt'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='LWS', pos='NN', lemma='LWS'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='Sie', pos='PPER', lemma='Sie'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='nicht', pos='PTKNEG', lemma='nicht'),
#  Tag(word='bewusstlos', pos='ADJD', lemma='bewusstlos'),
#  Tag(word='gewesen', pos='VAPP', lemma='sein'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='könne', pos='VMFIN', lemma='können'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='alles', pos='PIS', lemma='alle'),
#  Tag(word='erinnern', pos='VVFIN', lemma='erinnern'),
#  Tag(word='Keine', pos='PIAT', lemma='keine'),
#  Tag(word='Übelkeit', pos='NN', lemma='Übelkeit'),
#  Tag(word='kein', pos='PIAT', lemma='keine'),
#  Tag(word='Erbrechen', pos='NN', lemma='Erbrechen'),
#  Tag(word='Bei', pos='APPR', lemma='bei'),
#  Tag(word='Eintreffen', pos='NN', lemma='Eintreffen'),
#  Tag(word='des', pos='ART', lemma='die'),
#  Tag(word='NA', pos='NE', lemma='NA'),
#  Tag(word='GCS', pos='NN', lemma='GCS'),
#  Tag(word='15', pos='CARD', lemma='@card@'),
#  Tag(word='Vorerkrankungen', pos='NN', lemma='Vorerkrankung'),
#  Tag(word='Faktor', pos='NN', lemma='Faktor'),
#  Tag(word='VII', pos='CARD', lemma='VII'),
#  Tag(word='Mangel', pos='NN', lemma='Mangel'),
#  Tag(word='Allergien', pos='NN', lemma='Allergie'),
#  Tag(word='Metamizol', pos='NN', lemma='Metamizol'),
#  Tag(word='Medikation', pos='NN', lemma='Medikation'),
#  Tag(word='keine', pos='PIAT', lemma='keine'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='li', pos='ADJA', lemma='li'),
#  Tag(word='Schienbein', pos='NN', lemma='Schienbein'),
#  Tag(word='gegen', pos='APPR', lemma='gegen'),
#  Tag(word='einen', pos='ART', lemma='eine'),
#  Tag(word='Kinderrollator', pos='NN', lemma='Kinderrollator'),
#  Tag(word='gestoßen', pos='VVPP', lemma='stoßen'),
#  Tag(word='Im', pos='APPRART', lemma='in+die'),
#  Tag(word='Rahmen', pos='NN', lemma='Rahmen'),
#  Tag(word='seiner', pos='PPOSAT', lemma='sein'),
#  Tag(word='beruflichen', pos='ADJA', lemma='beruflich'),
#  Tag(word='Tätigkeit', pos='NN', lemma='Tätigkeit'),
#  Tag(word='durch', pos='APPR', lemma='durch'),
#  Tag(word='eine', pos='ART', lemma='eine'),
#  Tag(word='fremde', pos='ADJA', lemma='fremd'),
#  Tag(word='Person', pos='NN', lemma='Person'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Daumen', pos='NN', lemma='Daumen'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='rechten', pos='ADJA', lemma='recht|rechts'),
#  Tag(word='Hand', pos='NN', lemma='Hand'),
#  Tag(word='gebissen', pos='VVPP', lemma='beißen'),
#  Tag(word='worden', pos='VAPP', lemma='werden'),
#  Tag(word='Habe', pos='NN', lemma='Habe'),
#  Tag(word='hierbei', pos='PAV', lemma='hierbei'),
#  Tag(word='stichfeste', pos='ADJA', lemma='stichfest'),
#  Tag(word='Handschuhe', pos='NN', lemma='Handschuh'),
#  Tag(word='getragen', pos='VVPP', lemma='tragen'),
#  Tag(word='Handschuh', pos='NN', lemma='Handschuh'),
#  Tag(word='allseits', pos='ADV', lemma='allseits'),
#  Tag(word='vollständig', pos='ADJD', lemma='vollständig'),
#  Tag(word='intakt', pos='ADJD', lemma='intakt'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Verletzte', pos='NN', lemma='Verletzte'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='Eis', pos='NN', lemma='Eis'),
#  Tag(word='ausgerutscht', pos='VVPP', lemma='ausrutschen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='rechte', pos='ADJA', lemma='recht|rechts'),
#  Tag(word='Seite', pos='NN', lemma='Seite'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='Dabei', pos='PAV', lemma='dabei'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='Kopf', pos='NN', lemma='Kopf'),
#  Tag(word='rechts', pos='ADV', lemma='rechts'),
#  Tag(word='frontal', pos='ADJD', lemma='frontal'),
#  Tag(word='sowie', pos='KON', lemma='sowie'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='linker', pos='ADJA', lemma='links'),
#  Tag(word='Hand', pos='NN', lemma='Hand'),
#  Tag(word='aufgekommen', pos='VVPP', lemma='aufkommen'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Patient', pos='NN', lemma='Patient'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='dass', pos='KOUS', lemma='dass'),
#  Tag(word='ihm', pos='PPER', lemma='er'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='Zug', pos='NN', lemma='Zug'),
#  Tag(word='rangieren', pos='VVFIN', lemma='rangieren'),
#  Tag(word='um', pos='APPR', lemma='um'),
#  Tag(word='ca', pos='NE', lemma='ca'),
#  Tag(word='19', pos='CARD', lemma='@card@'),
#  Tag(word='30', pos='CARD', lemma='@card@'),
#  Tag(word='Uhr', pos='NN', lemma='Uhr'),
#  Tag(word='ein', pos='ART', lemma='eine'),
#  Tag(word='anderer', pos='ADJA', lemma='andere'),
#  Tag(word='ICE', pos='NE', lemma='ICE'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='geringer', pos='ADJA', lemma='gering'),
#  Tag(word='Geschwindigkeit', pos='NN', lemma='Geschwindigkeit'),
#  Tag(word='hinten', pos='ADV', lemma='hinten'),
#  Tag(word='aufgefahren', pos='VVPP', lemma='auffahren'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Pat', pos='NE', lemma='Pat'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Schafweide', pos='NN', lemma='Schafweide'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='hat', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='rechte', pos='ADJA', lemma='recht|rechts'),
#  Tag(word='Knie', pos='NE', lemma='Knie'),
#  Tag(word='verdreht', pos='VVPP', lemma='verdrehen'),
#  Tag(word='3673', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='Chahoud', pos='NE', lemma='Chahoud'),
#  Tag(word='Heu', pos='NN', lemma='Heu'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='gibt', pos='VVFIN', lemma='geben'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='08', pos='ADJA', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='einen', pos='ART', lemma='eine'),
#  Tag(word='Verkehrsunfall', pos='NN', lemma='Verkehrsunfall'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='A3', pos='NN', lemma='A3'),
#  Tag(word='erlitten', pos='VVPP', lemma='erleiden'),
#  Tag(word='zu', pos='PTKZU', lemma='zu'),
#  Tag(word='haben', pos='VAINF', lemma='haben'),
#  Tag(word='anschl', pos='VVFIN', lemma='anschl'),
#  Tag(word='wurde', pos='VAFIN', lemma='werden'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Offenbacher', pos='ADJA', lemma='Offenbacher'),
#  Tag(word='Klinikum', pos='NN', lemma='Klinikum'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Überwachung', pos='NN', lemma='Überwachung'),
#  Tag(word='stationär', pos='ADJD', lemma='stationär'),
#  Tag(word='aufgenommen', pos='VVPP', lemma='aufnehmen'),
#  Tag(word='Asklebius', pos='NE', lemma='Asklebius'),
#  Tag(word='Klinik', pos='NN', lemma='Klinik'),
#  Tag(word='Offenbach', pos='NE', lemma='Offenbach'),
#  Tag(word='Bei', pos='APPR', lemma='bei'),
#  Tag(word='unauffälligem', pos='ADJA', lemma='unauffällig'),
#  Tag(word='Verlauf', pos='NN', lemma='Verlauf'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='nächsten', pos='ADJA', lemma='nah'),
#  Tag(word='Tag', pos='NN', lemma='Tag'),
#  Tag(word='planmäßig', pos='ADJD', lemma='planmäßig'),
#  Tag(word='entlassen', pos='VVPP', lemma='entlassen'),
#  Tag(word='worden', pos='VAPP', lemma='werden'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='stellt', pos='VVFIN', lemma='stellen'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='nun', pos='ADV', lemma='nun'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='30', pos='ADJA', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='unserem', pos='PPOSAT', lemma='unser'),
#  Tag(word='Hause', pos='NN', lemma='Haus'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='persistierenden', pos='ADJA', lemma='persistierend'),
#  Tag(word='Kopfschmerzen', pos='NN', lemma='Kopfschmerz'),
#  Tag(word='vor', pos='PTKVZ', lemma='vor'),
#  Tag(word='Uv', pos='NE', lemma='Uv'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='ein', pos='ART', lemma='eine'),
#  Tag(word='Hubwagen', pos='NN', lemma='Hubwagen'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='li', pos='ADJA', lemma='li'),
#  Tag(word='Ferse', pos='NN', lemma='Ferse'),
#  Tag(word='gefahren', pos='VVPP', lemma='fahren'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Fuß', pos='NN', lemma='Fuß'),
#  Tag(word='weggeknickt', pos='VVPP', lemma='wegknicken'),
#  Tag(word='Fahrradunfall', pos='NN', lemma='Fahrradunfall'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Weg', pos='NN', lemma='Weg'),
#  Tag(word='von', pos='APPR', lemma='von'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Nähe', pos='NN', lemma='Nähe'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Waller', pos='NN', lemma='Waller'),
#  Tag(word='Heerstraße', pos='NN', lemma='Heerstraße'),
#  Tag(word='nach', pos='APPR', lemma='nach'),
#  Tag(word='Hause', pos='NN', lemma='Haus'),
#  Tag(word='Beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='Fahrradfahren', pos='NN', lemma='Fahrradfahren'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='ein', pos='ART', lemma='eine'),
#  Tag(word='anderer', pos='ADJA', lemma='andere'),
#  Tag(word='Fahrradfahrer', pos='NN', lemma='Fahrradfahrer'),
#  Tag(word='entgegengekommen', pos='VVPP', lemma='entgegenkommen'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='Linkshänder', pos='NN', lemma='Linkshänder'),
#  Tag(word='Wunde', pos='NN', lemma='Wunde'),
#  Tag(word='linker', pos='ADJA', lemma='links'),
#  Tag(word='Mittelfinger', pos='NN', lemma='Mittelfinger'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Versicherte', pos='NN', lemma='Versicherte'),
#  Tag(word='als', pos='KOKOM', lemma='als'),
#  Tag(word='Reiningungskraft', pos='NN', lemma='Reiningungskraft'),
#  Tag(word='beschäftigt', pos='VVPP', lemma='beschäftigen'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='Treppe', pos='NN', lemma='Treppe'),
#  Tag(word='rückwärtsgehend', pos='ADJD', lemma='rückwärtsgehend'),
#  Tag(word='ausgeruscht', pos='VVPP', lemma='ausgeruscht'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Rücken', pos='NN', lemma='Rücken'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='zu', pos='PTKZU', lemma='zu'),
#  Tag(word='sein', pos='VAINF', lemma='sein'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Vorstellung', pos='NN', lemma='Vorstellung'),
#  Tag(word='erfolgt', pos='VVFIN', lemma='erfolgen'),
#  Tag(word='zu', pos='APPR', lemma='zu'),
#  Tag(word='Fuß', pos='NN', lemma='Fuß'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='Schmerzen', pos='NN', lemma='Schmerz'),
#  Tag(word='eben', pos='ADV', lemma='eben'),
#  Tag(word='dort', pos='ADV', lemma='dort'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='etwas', pos='ADV', lemma='etwas'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Keller', pos='NN', lemma='Keller'),
#  Tag(word='bringen', pos='VVINF', lemma='bringen'),
#  Tag(word='wollen', pos='VMFIN', lemma='wollen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='Tür', pos='NN', lemma='Tür'),
#  Tag(word='ähnliche', pos='ADJA', lemma='ähnlich'),
#  Tag(word='wir', pos='PPER', lemma='wir'),
#  Tag(word='Feuerschutztür', pos='NN', lemma='Feuerschutztür'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Finger', pos='NN', lemma='Finger'),
#  Tag(word='eingeklemmt', pos='VVPP', lemma='einklemmen'),
#  Tag(word='Auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Weg', pos='NN', lemma='Weg'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Fahrrad', pos='NN', lemma='Fahrrad'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='linke', pos='ADJA', lemma='links'),
#  Tag(word='Körperseite', pos='NN', lemma='Körperseite'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='Z', pos='NN', lemma='Z'),
#  Tag(word='1', pos='CARD', lemma='@card@'),
#  Tag(word='Al', pos='NE', lemma='Al'),
#  Tag(word='4', pos='CARD', lemma='@card@'),
#  Tag(word='2', pos='CARD', lemma='@card@'),
#  Tag(word='ß', pos='ADJA', lemma='ß'),
#  Tag(word='tiM', pos='ADJA', lemma='tiM'),
#  Tag(word='rke', pos='ADJA', lemma='rke'),
#  Tag(word="'", pos='$(', lemma="'"),
#  Tag(word='wr', pos='NN', lemma='wr'),
#  Tag(word='LF', pos='NE', lemma='LF'),
#  Tag(word='dl', pos='NN', lemma='dl'),
#  Tag(word='gier', pos='VVIMP', lemma='gieren'),
#  Tag(word='10', pos='CARD', lemma='@card@'),
#  Tag(word='1', pos='CARD', lemma='@card@'),
#  Tag(word='2', pos='CARD', lemma='@card@'),
#  Tag(word='u', pos='ADJA', lemma='u'),
#  Tag(word='ß', pos='ADJA', lemma='ß'),
#  Tag(word='Un', pos='NE', lemma='un'),
#  Tag(word='042', pos='CARD', lemma='@card@'),
#  Tag(word='0', pos='CARD', lemma='@card@'),
#  Tag(word='06', pos='ADJA', lemma='@card@'),
#  Tag(word='24', pos='CARD', lemma='@card@'),
#  Tag(word='juerr', pos='NN', lemma='juerr'),
#  Tag(word='cg', pos='NE', lemma='cg'),
#  Tag(word='0', pos='ADJA', lemma='@card@'),
#  Tag(word='al', pos='NE', lemma='al'),
#  Tag(word='reo', pos='NE', lemma='reo'),
#  Tag(word='4', pos='CARD', lemma='@card@'),
#  Tag(word='01', pos='ADJA', lemma='@card@'),
#  Tag(word='Jä', pos='NE', lemma='Jä'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='ht', pos='NN', lemma='ht'),
#  Tag(word='j', pos='NE', lemma='j'),
#  Tag(word='JUW', pos='NN', lemma='JUW'),
#  Tag(word='26', pos='CARD', lemma='@card@'),
#  Tag(word='05', pos='CARD', lemma='@card@'),
#  Tag(word='914', pos='CARD', lemma='@card@'),
#  Tag(word='Ce', pos='ADJA', lemma='Ce'),
#  Tag(word='2010', pos='CARD', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='Voll', pos='ADJD', lemma='voll'),
#  Tag(word='s60', pos='ADJA', lemma='s@card@'),
#  Tag(word='kbe', pos='NN', lemma='kbe'),
#  Tag(word='20', pos='CARD', lemma='@card@'),
#  Tag(word='Lige', pos='VVFIN', lemma='Lige'),
#  Tag(word='10', pos='CARD', lemma='@card@'),
#  Tag(word='spk', pos='NN', lemma='spk'),
#  Tag(word='fk', pos='NN', lemma='fk'),
#  Tag(word='Beavn', pos='NN', lemma='Beavn'),
#  Tag(word='ir', pos='ADJA', lemma='ir'),
#  Tag(word='A', pos='NN', lemma='A'),
#  Tag(word='0', pos='CARD', lemma='@card@'),
#  Tag(word='urrA', pos='NN', lemma='urrA'),
#  Tag(word='3', pos='CARD', lemma='@card@'),
#  Tag(word='di', pos='NE', lemma='di'),
#  Tag(word='3151', pos='CARD', lemma='@card@'),
#  Tag(word='t', pos='NN', lemma='t'),
#  Tag(word='t', pos='NN', lemma='t'),
#  Tag(word='VA', pos='NN', lemma='VA'),
#  Tag(word="'2", pos='CARD', lemma='@card@'),
#  Tag(word='4', pos='CARD', lemma='@card@'),
#  Tag(word='lq', pos='NN', lemma='lq'),
#  Tag(word='Alf', pos='NE', lemma='Alf'),
#  Tag(word='2A', pos='NE', lemma='2A'),
#  Tag(word='r', pos='NE', lemma='r'),
#  Tag(word='5', pos='CARD', lemma='@card@'),
#  Tag(word='Ag', pos='VVPP', lemma='Ag'),
#  Tag(word='Während', pos='KOUS', lemma='während'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='als', pos='KOKOM', lemma='als'),
#  Tag(word='Praktikantin', pos='NN', lemma='Praktikantin'),
#  Tag(word='durch', pos='APPR', lemma='durch'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='Arbeitsamt', pos='NN', lemma='Arbeitsamt'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='wollte', pos='VMFIN', lemma='wollen'),
#  Tag(word='einen', pos='ART', lemma='eine'),
#  Tag(word='Teppich', pos='NN', lemma='Teppich'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Teppichmesser', pos='NN', lemma='Teppichmesser'),
#  Tag(word='schneiden', pos='VVINF', lemma='schneiden'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='abgerutscht', pos='VVPP', lemma='abrutschen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='hat', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='linken', pos='ADJA', lemma='links'),
#  Tag(word='Daumen', pos='NN', lemma='Daumen'),
#  Tag(word='geschnitten', pos='VVPP', lemma='schneiden'),
#  Tag(word='Gegen', pos='APPR', lemma='gegen'),
#  Tag(word='Tetanus', pos='NN', lemma='Tetanus'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='vor', pos='APPR', lemma='vor'),
#  Tag(word='weniger', pos='ADV', lemma='weniger'),
#  Tag(word='als', pos='KOKOM', lemma='als'),
#  Tag(word='10', pos='CARD', lemma='@card@'),
#  Tag(word='Jahren', pos='NN', lemma='Jahr'),
#  Tag(word='zuletzt', pos='ADV', lemma='zuletzt'),
#  Tag(word='geimpft', pos='VVPP', lemma='impfen'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='28', pos='ADJA', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='Putzarbeiten', pos='NN', lemma='Putzarbeit'),
#  Tag(word='aus', pos='APPR', lemma='aus'),
#  Tag(word='gebückter', pos='ADJA', lemma='gebückt'),
#  Tag(word='Position', pos='NN', lemma='Position'),
#  Tag(word='heraus', pos='ADV', lemma='heraus'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='Gleichgewicht', pos='NN', lemma='Gleichgewicht'),
#  Tag(word='verloren', pos='VVPP', lemma='verlieren'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='rücklings', pos='ADV', lemma='rücklings'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='linke', pos='ADJA', lemma='links'),
#  Tag(word='Seite', pos='NN', lemma='Seite'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='Seitdem', pos='PAV', lemma='seitdem'),
#  Tag(word='beklagt', pos='VVFIN', lemma='beklagen'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='persistierende', pos='ADJA', lemma='persistierende'),
#  Tag(word='Schmerzen', pos='NN', lemma='Schmerz'),
#  Tag(word='im', pos='APPRART', lemma='in+die'),
#  Tag(word='unteren', pos='ADJA', lemma='unter'),
#  Tag(word='Rücken', pos='NN', lemma='Rücken'),
#  Tag(word='linksseitig', pos='ADJD', lemma='linksseitig'),
#  Tag(word='linkes', pos='ADJA', lemma='links'),
#  Tag(word='Gesäß', pos='NN', lemma='Gesäß'),
#  Tag(word='Bisher', pos='ADV', lemma='bisher'),
#  Tag(word='kein', pos='PIAT', lemma='keine'),
#  Tag(word='ärztlicher', pos='ADJA', lemma='ärztlich'),
#  Tag(word='Kontakt', pos='NN', lemma='Kontakt'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='keine', pos='PIAT', lemma='keine'),
#  Tag(word='Einnahme', pos='NN', lemma='Einnahme'),
#  Tag(word='von', pos='APPR', lemma='von'),
#  Tag(word='Schmerzmedikamenten', pos='NN', lemma='Schmerzmedikament'),
#  Tag(word='Vorstellung', pos='NN', lemma='Vorstellung'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='Begleitung', pos='NN', lemma='Begleitung'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Angehörigen', pos='NN', lemma='Angehörige'),
#  Tag(word='die', pos='PDS', lemma='die'),
#  Tag(word='übersetzen', pos='VVFIN', lemma='übersetzen'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='spricht', pos='VVFIN', lemma='sprechen'),
#  Tag(word='kein', pos='PIAT', lemma='keine'),
#  Tag(word='deutsch', pos='ADJD', lemma='deutsch'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='Uv', pos='NE', lemma='Uv'),
#  Tag(word='gibt', pos='VVFIN', lemma='geben'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='ihm', pos='PPER', lemma='er'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='nach', pos='APPR', lemma='nach'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Vorstellung', pos='NN', lemma='Vorstellung'),
#  Tag(word='beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='applaudieren', pos='VVFIN', lemma='applaudieren'),
#  Tag(word='ein', pos='ART', lemma='eine'),
#  Tag(word='Kollege', pos='NN', lemma='Kollege'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Fuss', pos='NN', lemma='Fuß'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='Schuhwerk', pos='NN', lemma='Schuhwerk'),
#  Tag(word='getreten', pos='VVPP', lemma='treten'),
#  Tag(word='Ev', pos='NE', lemma='Ev'),
#  Tag(word='im', pos='APPRART', lemma='in+die'),
#  Tag(word='Marienhospital', pos='NN', lemma='Marienhospital'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='hatte', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Teppichcutter', pos='NN', lemma='Teppichcutter'),
#  Tag(word='versehentlich', pos='ADJD', lemma='versehentlich'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='linken', pos='ADJA', lemma='links'),
#  Tag(word='Daumen', pos='NN', lemma='Daumen'),
#  Tag(word='verletzt', pos='VVFIN', lemma='verletzen'),
#  Tag(word='Tetanus', pos='NN', lemma='Tetanus'),
#  Tag(word='Impfschutz', pos='NN', lemma='Impfschutz'),
#  Tag(word='anamnest', pos='ADJD', lemma='anamnest'),
#  Tag(word='intakt', pos='ADJD', lemma='intakt'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Pat', pos='NE', lemma='Pat'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='letzte', pos='ADJA', lemma='letzt'),
#  Tag(word='Treppenstufe', pos='NN', lemma='Treppenstufe'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='linken', pos='ADJA', lemma='links'),
#  Tag(word='Arm', pos='NN', lemma='Arm'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='unfallversicherte', pos='ADJA', lemma='unfallversichert'),
#  Tag(word='Person', pos='NN', lemma='Person'),
#  Tag(word='war', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Weg', pos='NN', lemma='Weg'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='seinem', pos='PPOSAT', lemma='sein'),
#  Tag(word='Fahrrad', pos='NN', lemma='Fahrrad'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Tiefgarage', pos='NN', lemma='Tiefgarage'),
#  Tag(word='ins', pos='APPRART', lemma='in+die'),
#  Tag(word='rutschen', pos='VVFIN', lemma='rutschen'),
#  Tag(word='gekommen', pos='ADJD', lemma='gekommen'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='verletzte', pos='VVFIN', lemma='verletzen'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Daumen', pos='NN', lemma='Daumen'),
#  Tag(word='kommt', pos='VVFIN', lemma='kommen'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='Überweisung', pos='NN', lemma='Überweisung'),
#  Tag(word='vom', pos='APPRART', lemma='von+die'),
#  Tag(word='HA', pos='NE', lemma='HA'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='klagt', pos='VVFIN', lemma='klagen'),
#  Tag(word='über', pos='APPR', lemma='über'),
#  Tag(word='verstärkete', pos='NN', lemma='verstärkete'),
#  Tag(word='Kopfschmezren', pos='NN', lemma='Kopfschmezren'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='Augentränen', pos='NN', lemma='Augenträne|Augentränen'),
#  Tag(word='sieht', pos='VVFIN', lemma='sehen'),
#  Tag(word='verschwommen', pos='VVPP', lemma='verschwimmen'),
#  Tag(word='seitdem', pos='PAV', lemma='seitdem'),
#  Tag(word='Wochenende', pos='NN', lemma='Wochenende'),
#  Tag(word='nach', pos='APPR', lemma='nach'),
#  Tag(word='Trauma', pos='NN', lemma='Trauma'),
#  Tag(word='27', pos='CARD', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='18', pos='CARD', lemma='@card@'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='jetzt', pos='ADV', lemma='jetzt'),
#  Tag(word='auch', pos='ADV', lemma='auch'),
#  Tag(word='über', pos='APPR', lemma='über'),
#  Tag(word='Hämatom', pos='NN', lemma='Hämatom'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Auge', pos='NN', lemma='Auge'),
#  Tag(word='Übergeben', pos='NN', lemma='Übergeben'),
#  Tag(word='musste', pos='VMFIN', lemma='müssen'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Patienitn', pos='NN', lemma='Patienitn'),
#  Tag(word='nicht', pos='PTKNEG', lemma='nicht'),
#  Tag(word='mehr', pos='ADV', lemma='mehr'),
#  Tag(word='Ibu', pos='ADJD', lemma='Ibu'),
#  Tag(word='600', pos='CARD', lemma='@card@'),
#  Tag(word='hilft', pos='VVFIN', lemma='helfen'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='Kopfschmerzen', pos='NN', lemma='Kopfschmerz'),
#  Tag(word='Gestern', pos='ADV', lemma='gestern'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='Weg', pos='NN', lemma='Weg'),
#  Tag(word='zur', pos='APPRART', lemma='zu+die'),
#  Tag(word='Arbeit', pos='NN', lemma='Arbeit'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='nassen', pos='ADJA', lemma='nass'),
#  Tag(word='Außentreppeausgerutscht', pos='NN', lemma='Außentreppeausgerutscht'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='rückwärts', pos='ADV', lemma='rückwärts'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='Gesäß', pos='NN', lemma='Gesäß'),
#  Tag(word='gefallen', pos='VVPP', lemma='fallen|gefallen'),
#  Tag(word='seither', pos='ADV', lemma='seither'),
#  Tag(word='Schmerzen', pos='NN', lemma='Schmerz'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='war', pos='VAFIN', lemma='sein'),
#  Tag(word='bei', pos='APPR', lemma='bei'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='Besprechung', pos='NN', lemma='Besprechung'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='schließendem', pos='ADJA', lemma='schließendem'),
#  Tag(word='Betriebsrundgang', pos='NN', lemma='Betriebsrundgang'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='hat', pos='VAFIN', lemma='haben'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='eine', pos='ART', lemma='eine'),
#  Tag(word='Treppenstufe', pos='NN', lemma='Treppenstufe'),
#  Tag(word='beim', pos='APPRART', lemma='bei+die'),
#  Tag(word='hinuntergehen', pos='VVINF', lemma='hinuntergehen'),
#  Tag(word='übersehen', pos='VVINF', lemma='übersehen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='das', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Knie', pos='NE', lemma='Knie'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='dieses', pos='PDAT', lemma='dies'),
#  Tag(word='hat', pos='VAFIN', lemma='haben'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='dabei', pos='PAV', lemma='dabei'),
#  Tag(word='verletzt', pos='VVPP', lemma='verletzen'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='dass', pos='KOUS', lemma='dass'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Zebrastreifen', pos='NN', lemma='Zebrastreifen'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='dem', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Fuß', pos='NN', lemma='Fuß'),
#  Tag(word='umgeknickt', pos='VVPP', lemma='umknicken'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='gestürtzt', pos='ADJA', lemma='gestürtzt'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='Ein', pos='ART', lemma='eine'),
#  Tag(word='Auto', pos='NN', lemma='Auto'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='sie', pos='PPER', lemma='sie'),
#  Tag(word='leicht', pos='ADJD', lemma='leicht'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Ferse', pos='NN', lemma='Ferse'),
#  Tag(word='angefahren', pos='VVPP', lemma='anfahren'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='verletze', pos='VVFIN', lemma='verletzen'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='am', pos='APPRART', lemma='an+die'),
#  Tag(word='17', pos='ADJA', lemma='@card@'),
#  Tag(word='12', pos='CARD', lemma='@card@'),
#  Tag(word='2018', pos='CARD', lemma='@card@'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Kontainerwagen', pos='NN', lemma='Kontainerwagen'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Fuß', pos='NN', lemma='Fuß'),
#  Tag(word='Der', pos='ART', lemma='die'),
#  Tag(word='UV', pos='NE', lemma='UV'),
#  Tag(word='berichtet', pos='VVFIN', lemma='berichten'),
#  Tag(word='dass', pos='KOUS', lemma='dass'),
#  Tag(word='er', pos='PPER', lemma='er'),
#  Tag(word='im', pos='APPRART', lemma='in+die'),
#  Tag(word='Rahmen', pos='NN', lemma='Rahmen'),
#  Tag(word='seiner', pos='PPOSAT', lemma='sein'),
#  Tag(word='beruflichen', pos='ADJA', lemma='beruflich'),
#  Tag(word='Tätigkeit', pos='NN', lemma='Tätigkeit'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='eine', pos='ART', lemma='eine'),
#  Tag(word='Verletzung', pos='NN', lemma='Verletzung'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='einem', pos='ART', lemma='eine'),
#  Tag(word='Meiselsplitter', pos='NN', lemma='Meiselsplitter'),
#  Tag(word='an', pos='APPR', lemma='an'),
#  Tag(word='D2', pos='NN', lemma='D2'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='re', pos='ADJA', lemma='re'),
#  Tag(word='Hand', pos='NN', lemma='Hand'),
#  Tag(word='zugezogen', pos='VVPP', lemma='zuziehen'),
#  Tag(word='habe', pos='VAFIN', lemma='haben'),
#  Tag(word='Die', pos='ART', lemma='die'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='ist', pos='VAFIN', lemma='sein'),
#  Tag(word='auf', pos='APPR', lemma='auf'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='internistischen', pos='ADJA', lemma='internistisch'),
#  Tag(word='Station', pos='NN', lemma='Station'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='domo', pos='ADJD', lemma='domo'),
#  Tag(word='gestürzt', pos='VVPP', lemma='stürzen'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='gibt', pos='VVFIN', lemma='geben'),
#  Tag(word='jetzt', pos='ADV', lemma='jetzt'),
#  Tag(word='Schmerzen', pos='NN', lemma='Schmerz'),
#  Tag(word='im', pos='APPRART', lemma='in+die'),
#  Tag(word='Becken', pos='NN', lemma='Becken'),
#  Tag(word='und', pos='KON', lemma='und'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='linken', pos='ADJA', lemma='links'),
#  Tag(word='Hüfte', pos='NN', lemma='Hüfte'),
#  Tag(word='an', pos='PTKVZ', lemma='an'),
#  Tag(word='UT', pos='NE', lemma='UT'),
#  Tag(word='10', pos='CARD', lemma='@card@'),
#  Tag(word='01', pos='ADJA', lemma='@card@'),
#  Tag(word='19', pos='CARD', lemma='@card@'),
#  Tag(word='gegen', pos='APPR', lemma='gegen'),
#  Tag(word='16', pos='CARD', lemma='@card@'),
#  Tag(word='00Uhr', pos='NN', lemma='00Uhr'),
#  Tag(word='hat', pos='VAFIN', lemma='haben'),
#  Tag(word='sich', pos='PRF', lemma='sich'),
#  Tag(word='die', pos='ART', lemma='die'),
#  Tag(word='Pat', pos='NE', lemma='Pat'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='li', pos='ADJA', lemma='li'),
#  Tag(word='Daumen', pos='NN', lemma='Daumen'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Tür', pos='NN', lemma='Tür'),
#  Tag(word='im', pos='APPRART', lemma='in+die'),
#  Tag(word='Kinderzentrum', pos='NN', lemma='Kinderzentrum'),
#  Tag(word='eingeklemmt', pos='VVPP', lemma='einklemmen'),
#  Tag(word='Patientin', pos='NN', lemma='Patientin'),
#  Tag(word='sei', pos='VAFIN', lemma='sein'),
#  Tag(word='während', pos='APPR', lemma='während'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Arbeitszeit', pos='NN', lemma='Arbeitszeit'),
#  Tag(word='mit', pos='APPR', lemma='mit'),
#  Tag(word='einer', pos='ART', lemma='eine'),
#  Tag(word='Tasse', pos='NN', lemma='Tasse'),
#  Tag(word='in', pos='APPR', lemma='in'),
#  Tag(word='der', pos='ART', lemma='die'),
#  Tag(word='Hand', pos='NN', lemma='Hand'),
#  Tag(word='über', pos='APPR', lemma='über'),
#  Tag(word='den', pos='ART', lemma='die'),
#  Tag(word='Fuß', pos='NN', lemma='Fuß'),
#  Tag(word='ihres', pos='PPOSAT', lemma='ihr'),
#  Tag(word='Schreibtischstuhles', pos='NN', lemma='Schreibtischstuhl'),
#  ...]

# %%
import treetaggerwrapper
#1) build a TreeTagger wrapper:
#tagger = treetaggerwrapper.TreeTagger(TAGLANG='de', TAGDIR='treetagger/')
#2) tag your text.
#tags = tagger.tag_text("This is a very short text to tag.")
#3) use the tags list... (list of string output from TreeTagger).
#pprint.pprint(tags)

filename=open("/content/drive/MyDrive/vbg/test_part.txt","r")
tree_tagger = treetaggerwrapper.TreeTagger(TAGLANG='de', TAGDIR='treetagger/')
tokenizer = nltk.RegexpTokenizer("[\w']+")
tags = []
for line in filename.readlines():
    tags+=tree_tagger.tag_text(tokenizer.tokenize(line), tagonly=True)
tags2 = treetaggerwrapper.make_tags(tags)
#tokens_part = [token.lower() for token in tokens_part]
#nltk.FreqDist(tokens_part).plot(20, cumulative=False)
#tags = tree_tagger.tag_text(tokens_part,tagonly=True) #don't use the TreeTagger's tokenization!
lemmas_part = [lemma for (word,pos,lemma) in tags2]
print(lemmas_part)
# Out:
ht', 'bewusstlos', 'sein', 'sie', 'können', 'sich', 'an', 'alle', 'erinnern', 'keine', 'Übelkeit', 'keine', 'Erbrechen', 'bei', 'Eintreffen', 'die', 'NA', 'GCS', '@card@', 'Vorerkrankung', 'Faktor', 'VII', 'Mangel', 'Allergie', 'Metamizol', 'Medikation', 'keine', 'die', 'UV', 'sein', 'mit', 'die', 'li', 'Schienbein', 'gegen', 'eine', 'Kinderrollator', 'stoßen', 'in+die', 'Rahmen', 'sein', 'beruflich', 'Tätigkeit', 'durch', 'eine', 'fremd', 'Person', 'in', 'die', 'Daumen', 'die', 'recht|rechts', 'Hand', 'beißen', 'werden', 'Habe', 'hierbei', 'stichfest', 'Handschuh', 'tragen', 'Handschuh', 'allseits', 'vollständig', 'intakt', 'die', 'Verletzte', 'sein', 'auf', 'Eis', 'ausrutschen', 'und', 'auf', 'die', 'recht|rechts', 'Seite', 'fallen|gefallen', 'dabei', 'mit', 'Kopf', 'rechts', 'frontal', 'sowie', 'mit', 'links', 'Hand', 'aufkommen', 'die', 'Patient', 'berichten', 'dass', 'er', 'in', 'die', 'Arbeit', 'bei+die', 'Zug', 'rangieren', 'um', 'ca', '@card@', '@card@', 'Uhr', 'eine', 'andere', 'ICE', 'mit', 'gering', 'Geschwindigkeit', 'hinten', 'auffahren', 'sein', 'die', 'Pat', 'sein', 'auf', 'die', 'Schafweide', 'stürzen', 'und', 'haben', 'sich', 'die', 'recht|rechts', 'Knie', 'verdrehen', '@card@', '@card@', 'Chahoud', 'Heu', 'die', 'UV', 'geben', 'an', 'an+die', '@card@', '@card@', '@card@', 'eine', 'Verkehrsunfall', 'auf', 'die', 'A3', 'erleiden', 'zu', 'haben', 'anschl', 'werden', 'die', 'UV', 'in', 'eine', 'Offenbacher', 'Klinikum', 'zu+die', 'Überwachung', 'stationär', 'aufnehme ...

# %%
# Rougly 5 minutes
filename=open("/content/drive/MyDrive/vbg/test.txt","r")
tree_tagger = treetaggerwrapper.TreeTagger(TAGLANG='de', TAGDIR='treetagger/')
tokenizer = nltk.RegexpTokenizer("[\w']+")
tags = []
for line in filename.readlines():
    tags+=tree_tagger.tag_text(tokenizer.tokenize(line), tagonly=True)
tags2 = treetaggerwrapper.make_tags(tags)
lemmas = [lemma for (word,pos,lemma) in tags2]
#print(lemmas_part)
nltk.FreqDist(lemmas).plot(20, cumulative=False)

# %%
lemmas = [lemma for (word,lemma,pos) in tags]
nltk.FreqDist(lemmas_part).plot(20, cumulative=False)

# %%
import treetaggerwrapper
import nltk
filename=open("/content/drive/MyDrive/vbg/test_10.txt","r")
tree_tagger = treetaggerwrapper.TreeTagger(TAGLANG='de', TAGDIR='treetagger/')
tokenizer = nltk.RegexpTokenizer("[\w']+")
tags = []
for line in filename.readlines():
    tags+=tree_tagger.tag_text(tokenizer.tokenize(line), tagonly=True)
tags2 = treetaggerwrapper.make_tags(tags)
lemmas = [lemma for (word,pos,lemma) in tags2]
#print(lemmas_part)
nltk.FreqDist(lemmas).plot(20, cumulative=False)
