# %%
import pandas as pd
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Einlesen der Datei "DatenAnonymisiert_ansi_part.csv" mit [pd.read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
daten =

# %% [markdown]
# Eine Variable "daten_nltk" erstellen, die nur die Spalte "UNFALLHERGANG" enthält

# %%
daten_nltk = 
daten_nltk
# Out:
# LNR
# 1     Versicherter ist auf dem Fahrrad auf dem Nachh...
# 2     Unfallort:\nDer Pat. ist auf Glatteis ausgerut...
# 3     Auf dem WEg zur Arbeit auf Glatteis ausgerutsc...
# 4     Die Versicherte habe ein Garagentor auf dem Ko...
# 5     Fußläufige Vorstellung in unserer ZNA. Die Ver...
#                             ...
# 85    Vorstellung von Station Vollhard. Dort sei die...
# 86    Die Patientin ist gestern mit dem Fahrrad zur ...
# 87    Die Versicherte ist mit dem Fahrrad auf dem We...
# 88    Die UV gibt an, bei Reinigungsarbeiten den Kop...
# 89
# Name: UNFALLHERGANG, Length: 89, dtype: object

# %% [markdown]
# Eine Variable "daten_tokens" erstellen, die nur die erste Zeile des Objekts "daten_nltk" enthält und den Satz mit der Funktion [nltk.word_tokenize](https://www.nltk.org/api/nltk.tokenize.html) tokenisiert

# %%
daten_tokens = 
daten_tokens
# Out:
# ['Versicherter',
#  'ist',
#  'auf',
#  'dem',
#  'Fahrrad',
#  'auf',
#  'dem',
#  'Nachhauseweg',
#  'verunfallt',
#  '.',
#  'Ein',
#  'stehendes',
#  'Auto',
#  'habe',
#  'die',
#  'Tür',
#  'geöffnet',
#  ',',
#  'der',
#  'Versicherte',
#  'konnte',
#  'nicht',
#  'mehr',
#  'bremsen',
#  'und',
#  'ist',
#  'gegen',
#  'die',
#  'Autotür',
#  'gefahren',
#  '.',
#  'Versicherter',
#  'war',
#  'behelmt',
#  ',',
#  'kein',
#  'Kopfanprall',
#  '.',
#  'Tetanusschutz',
#  'nicht',
#  'sicher',
#  'intakt',
#  ',',
#  'wird',
#  'morgen',
#  'über',
#  'beim',
#  'niedergelassenen',
#  'Hausarzt',
#  'gprüft',
#  'und',
#  'ggf',
#  '.',
#  'nachgeholt',
#  '.',
#  'Unfallort',
#  'Berliner',
#  'Straße',
#  ',',
#  'Köln-Mühlheim']

# %% [markdown]
# Wie häufig kommt das Wort "Versicherter" im ersten Satz vor? Dazu die Funktion [concordance](https://avidml.wordpress.com/2017/08/05/natural-language-processing-concordance/) verwenden

# %%
nltk.Text(daten_tokens)[HIERAUSFÜLLEN]
# Out:
# Displaying 2 of 2 matches:
#                                  Versicherter ist auf dem Fahrrad auf dem Nach
# ist gegen die Autotür gefahren . Versicherter war behelmt , kein Kopfanprall .

# %% [markdown]
# An welchen Stellen kommen die Wörter "ist" und "Versicherter" vor? Dazu die Funktion [dispersion_plot](http://www.nltk.org/book_1ed/ch01.html#fig-inaugural) (Bitte beim Link etwas nach oben scrollen für den Beispielcode) verwenden

# %%
nltk.Text(daten_tokens)[HIERAUSFÜLLEN]

# %% [markdown]
# Erstellen Sie eine Liste über die Häufigkeit, mit der einzelne Tokens vorkommen und speichern diese in die Variable "counts". Bitte verwende dazu die Funktion [FreqDist](http://www.nltk.org/api/nltk.html#nltk.probability.FreqDist)

# %%
counts = 
counts
# Out:
# FreqDist({',': 4,
#           '.': 5,
#           'Auto': 1,
#           'Autotür': 1,
#           'Berliner': 1,
#           'Ein': 1,
#           'Fahrrad': 1,
#           'Hausarzt': 1,
#           'Kopfanprall': 1,
#           'Köln-Mühlheim': 1,
#           'Nachhauseweg': 1,
#           'Straße': 1,
#           'Tetanusschutz': 1,
#           'Tür': 1,
#           'Unfallort': 1,
#           'Versicherte': 1,
#           'Versicherter': 2,
#           'auf': 2,
#           'behelmt': 1,
#           'beim': 1,
#           'bremsen': 1,
#           'dem': 2,
#           'der': 1,
#           'die': 2,
#           'gefahren': 1,
#           'gegen': 1,
#           'geöffnet': 1,
#           'ggf': 1,
#           'gprüft': 1,
#           'habe': 1,
#           'intakt': 1,
#           'ist': 2,
#           'kein': 1,
#           'konnte': 1,
#           'mehr': 1,
#           'morgen': 1,
#           'nachgeholt': 1,
#           'nicht': 2,
#           'niedergelassenen': 1,
# ...

# %% [markdown]
# Lassen Sie sich die Liste in einer Grafik mit der Funktion "plot" visualisieren

# %%
counts.plot(20, cumulative=False)

# %% [markdown]
# Versuche nun, den selben Code mit der großen Datei (DatenAnobynisiert_ansi.CSV)
